# %% [markdown]
# # Data set: European Social Survey (ESS) - Human values scale
#
# * European Social Survey (ESS): https://ess-search.nsd.no/CDW/ConceptVariables
# * chosen topic "Human values scale"
# * chosen rounds: 4 + 9
# * chosen countries: Bulgaria, Germany, Spain, Sweden, United Kingdom
# * chosen questions: 'impenv','imprich', 'ipeqopt', 'iphlppl', 'ipstrgv'

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Data set/ESS-Data-Wizard-subset-2023-05-19.csv") #just round 9 data

# %% [markdown]
# ## Legend
#
# * impdiff - Important to try new and different things in life
# * impenv - Important to care for nature and environment
# * impfree - Important to make own decisions and be free
# * impfun - Important to seek fun and things that give pleasure
# * imprich - Important to be rich, have money and expensive things
# * impsafe - Important to live in secure and safe surroundings
# * imptrad - Important to follow traditions and customs
# * ipadvnt - Important to seek adventures and have an exciting life
# * ipbhprp - Important to behave properly
# * ipcrtiv - Important to think new ideas and being creative
# * ipeqopt - Important that people are treated equally and have equal opportunities
# * ipfrule - Important to do what is told and follow rules
# * ipgdtim - Important to have a good time
# * iphlppl - Important to help people and care for others well-being
# * iplylfr - Important to be loyal to friends and devote to people close
# * ipmodst - Important to be humble and modest, not draw attention
# * iprspot - Important to get respect from others
# * ipshabt - Important to show abilities and be admired
# * ipstrgv - Important that government is strong and ensures safety
# * ipsuces - Important to be successful and that people recognize achievements
# * ipudrst - Important to understand different people
#
# *Further information about the data set:*
# * **CODEBOOK**: http://localhost:8888/lab/tree/Documents/GitHub/DDRM4DH_2023S/Data%20set/ESS-Data-Wizard-subset-2023-05-11/ESS-Data-Wizard-subset-2023-05-11%20codebook.html

# %%
data.head()
# Out:
#         name  essround  edition    proddate  idno cntry  dweight   pspwght  \
# 0  ESS4e04_5         4      4.5  01.12.2018    11    BG   0.8285  1.115312
# 1  ESS4e04_5         4      4.5  01.12.2018    13    BG   0.4143  0.557723
# 2  ESS4e04_5         4      4.5  01.12.2018    15    BG   1.2428  1.734877
# 3  ESS4e04_5         4      4.5  01.12.2018    16    BG   1.2428  1.688932
# 4  ESS4e04_5         4      4.5  01.12.2018    17    BG   0.4143  0.557723
#
#     pweight  anweight  prob  stratum  psu  impenv  imprich  ipeqopt  iphlppl  \
# 0  0.296719       NaN   NaN      NaN  NaN       1        8        2        1
# 1  0.296719       NaN   NaN      NaN  NaN       1        4        3        1
# 2  0.296719       NaN   NaN      NaN  NaN       1        3        1        3
# 3  0.296719       NaN   NaN      NaN  NaN       2        3        2        2
# 4  0.296719       NaN   NaN      NaN  NaN       2        6        3        2
#
#    ipstrgv
# 0        1
# 1        2
# 2        1
# ...

# %%
data.columns
# Out:
# Index(['name', 'essround', 'edition', 'proddate', 'idno', 'cntry', 'dweight',
#        'pspwght', 'pweight', 'anweight', 'prob', 'stratum', 'psu', 'impenv',
#        'imprich', 'ipeqopt', 'iphlppl', 'ipstrgv'],
#       dtype='object')

# %%
print(data['cntry'].unique()) #countries --> Bulgaria, Germany, Spain, United Kingdom, Sweden
# Out:
# ['BG' 'DE' 'ES' 'GB' 'SE']

# %%
print(data['name'].unique()) #round 4 and round 9
# Out:
# ['ESS4e04_5' 'ESS9e03_1']

# %%
print(data['essround'].unique()) # ESS rounds of the data set
# Out:
# [4 9]

# %%
#dataframe: ROUND 4

round4 = ['ESS4e04_5']
df_round4 = data[data['name'].isin(round4)]
df_round4
# Out:
#             name  essround  edition    proddate       idno cntry  dweight  \
# 0      ESS4e04_5         4      4.5  01.12.2018         11    BG   0.8285
# 1      ESS4e04_5         4      4.5  01.12.2018         13    BG   0.4143
# 2      ESS4e04_5         4      4.5  01.12.2018         15    BG   1.2428
# 3      ESS4e04_5         4      4.5  01.12.2018         16    BG   1.2428
# 4      ESS4e04_5         4      4.5  01.12.2018         17    BG   0.4143
# ...          ...       ...      ...         ...        ...   ...      ...
# 11734  ESS4e04_5         4      4.5  01.12.2018  300029907    SE   1.0000
# 11735  ESS4e04_5         4      4.5  01.12.2018  300029931    SE   1.0000
# 11736  ESS4e04_5         4      4.5  01.12.2018  300029956    SE   1.0000
# 11737  ESS4e04_5         4      4.5  01.12.2018  300029964    SE   1.0000
# 11738  ESS4e04_5         4      4.5  01.12.2018  300029998    SE   1.0000
#
#         pspwght   pweight  anweight  prob  stratum  psu  impenv  imprich  \
# ...

# %%
#dataframe: ROUND 9

round9 = ['ESS9e03_1']
df_round9 = data[data['name'].isin(round9)]
df_round9
# Out:
#             name  essround  edition    proddate   idno cntry   dweight  \
# 11739  ESS9e03_1         9      3.1  17.02.2021      2    BG  1.121477
# 11740  ESS9e03_1         9      3.1  17.02.2021     27    BG  0.489820
# 11741  ESS9e03_1         9      3.1  17.02.2021     37    BG  1.199818
# 11742  ESS9e03_1         9      3.1  17.02.2021     50    BG  0.729412
# 11743  ESS9e03_1         9      3.1  17.02.2021     70    BG  1.100528
# ...          ...       ...      ...         ...    ...   ...       ...
# 21701  ESS9e03_1         9      3.1  17.02.2021  69836    SE  1.000000
# 21702  ESS9e03_1         9      3.1  17.02.2021  69845    SE  1.000000
# 21703  ESS9e03_1         9      3.1  17.02.2021  69882    SE  1.000000
# 21704  ESS9e03_1         9      3.1  17.02.2021  69908    SE  1.000000
# 21705  ESS9e03_1         9      3.1  17.02.2021  69934    SE  1.000000
#
#         pspwght   pweight  anweight      prob  stratum      psu  impenv  \
# ...

# %% [markdown]
# ## Visualization
#
# * Seaborn
# * matplotlib

# %% [markdown]
# ### imprich - Important to be rich, have money and expensive things
# **Value 	Category**
#
# * 1 	Very much like me
# * 2 	Like me
# * 3 	Somewhat like me
# * 4 	A little like me
# * 5 	Not like me
# * 6 	Not like me at all
# * 7 	Refusal*
# * 8 	Don't know*
# * 9 	No answer*
#
# *) Missing Value

# %%
#grouped poxplot; values of ROUND 4 and ROUND 9

sns.set_theme(style="ticks", palette="pastel")
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x=data['cntry'], y=data['imprich'], data=data)
sns.despine(offset=10, trim=True) #remove frame
plt.title("ROUND 4 & 9: imprich - Important to be rich, have money and expensive things", fontsize=18)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Value category', fontsize = 16)
#plt.savefig('boxplot_cntry.png', bbox_inches='tight')
plt.show()

# %%
#grouped poxplot; values of ROUND 4

sns.set_theme(style="ticks", palette="mako")
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x=df_round4['cntry'], y=df_round4['imprich'], data=df_round4)
sns.despine(offset=10, trim=True) #remove frame
plt.title("ROUND 4: imprich - Important to be rich, have money and expensive things", fontsize=18)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Value category', fontsize = 16)

#plt.savefig('boxplot_cntry.png', bbox_inches='tight')
plt.show()

# %%
#grouped poxplot; values of ROUND 9

sns.color_palette("husl", 9)
sns.set_theme(style="ticks", palette="mako") # SOMETHING's wrong!
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x=df_round9['cntry'], y=df_round9['imprich'], data=df_round9)
sns.despine(offset=10, trim=True) #remove frame
plt.title("ROUND 9: imprich - Important to be rich, have money and expensive things", fontsize=18)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Value category', fontsize = 16)
#plt.savefig('boxplot_cntry.png', bbox_inches='tight')
plt.show()

# %%
#imprich - comparison: round 4 vs. round 9

sns.set_theme(style="ticks", palette="mako")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

# Plot for round 4
sns.boxplot(x=df_round4['cntry'], y=df_round4['imprich'], data=df_round4, ax=ax1)
ax1.set_title("ROUND 4: imprich - Important to be rich, have money and expensive things", fontsize=18)
ax1.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 4 plot
sns.despine(offset=10, trim=True, ax=ax1)
ax1.tick_params(bottom=False)

# Plot for round 9
#sns.color_palette("Spectral", as_cmap=True)
sns.set_theme(style="ticks", palette="mako")
sns.boxplot(x=df_round9['cntry'], y=df_round9['imprich'], data=df_round9, ax=ax2)
ax2.set_title("ROUND 9: imprich - Important to be rich, have money and expensive things", fontsize=18)
ax2.set_xlabel('Countries', fontsize=16)
ax2.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 9 plot
sns.despine(offset=10, trim=True, ax=ax2)

# Adjust spacing between the two subplots
plt.subplots_adjust(hspace=0.2)

# UNCOMMENT to save boxplot
#plt.savefig('ipstrgv_boxplot_round4_9.png', bbox_inches='tight')

plt.show()

# %%
#ipstrgv - Important that government is strong and ensures safety

#grouped poxplot; values of ROUND 9

sns.color_palette("husl", 9)
sns.set_theme(style="ticks", palette="colorblind") # SOMETHING's wrong!
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x=df_round9['cntry'], y=df_round9['ipstrgv'], data=df_round9)
sns.despine(offset=10, trim=True) #remove frame
plt.title("ROUND 9: ipstrgv - Important that government is strong and ensures safety", fontsize=18)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Value category', fontsize = 16)
#plt.savefig('boxplot_cntry.png', bbox_inches='tight')
plt.show()

# %%
#grouped poxplot; values of ROUND 4 - 'ipstrgv'

sns.set_theme(style="ticks", palette="colorblind")
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x=df_round4['cntry'], y=df_round4['ipstrgv'], data=df_round4)
sns.despine(offset=10, trim=True) #remove frame
plt.title("ROUND 4: ipstrgv - Important that government is strong and ensures safety", fontsize=18)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Value category', fontsize = 16)

#plt.savefig('boxplot_cntry.png', bbox_inches='tight')
plt.show()

# %%
sns.set_theme(style="ticks", palette="colorblind")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

# Plot for round 4
sns.boxplot(x=df_round4['cntry'], y=df_round4['ipstrgv'], data=df_round4, ax=ax1)
ax1.set_title("ROUND 4: ipstrgv - Important that government is strong and ensures safety", fontsize=18)
ax1.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 4 plot
sns.despine(offset=10, trim=True, ax=ax1)
ax1.tick_params(bottom=False)

# Plot for round 9
#sns.color_palette("Spectral", as_cmap=True)
sns.set_theme(style="ticks", palette="colorblind")
sns.boxplot(x=df_round9['cntry'], y=df_round9['ipstrgv'], data=df_round9, ax=ax2)
ax2.set_title("ROUND 9: ipstrgv - Important that government is strong and ensures safety", fontsize=18)
ax2.set_xlabel('Countries', fontsize=16)
ax2.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 9 plot
sns.despine(offset=10, trim=True, ax=ax2)

# Adjust spacing between the two subplots
plt.subplots_adjust(hspace=0.2)

# UNCOMMENT to save boxplot
#plt.savefig('ipstrgv_boxplot_round4_9.png', bbox_inches='tight')

plt.show()

# %%
sns.set_theme(style="ticks", palette="Set1")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

# Plot for round 4
sns.boxplot(x=df_round4['cntry'], y=df_round4['ipeqopt'], data=df_round4, ax=ax1)
ax1.set_title("ROUND 4: ipeqopt - Important that people are treated equally and have equal opportunities", fontsize=18)
ax1.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 4 plot
sns.despine(offset=10, trim=True, ax=ax1)
ax1.tick_params(bottom=False)

# Plot for round 9
#sns.color_palette("Spectral", as_cmap=True)
sns.set_theme(style="ticks", palette="Set1")
sns.boxplot(x=df_round9['cntry'], y=df_round9['ipeqopt'], data=df_round9, ax=ax2)
ax2.set_title("ROUND 9: ipeqopt - Important that people are treated equally and have equal opportunities", fontsize=18)
ax2.set_xlabel('Countries', fontsize=16)
ax2.set_ylabel('Value category', fontsize=16)

# Remove frame and spines for round 9 plot
sns.despine(offset=10, trim=True, ax=ax2)

# Adjust spacing between the two subplots
plt.subplots_adjust(hspace=0.2)

# UNCOMMENT to save boxplot
#plt.savefig('ipstrgv_boxplot_round4_9.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# * ADJUST palette: https://seaborn.pydata.org/generated/seaborn.husl_palette.html
# * SEABORN palettes: https://r02b.github.io/seaborn_palettes/

# %% [markdown]
# ### Choosing the right graph:
# * https://www.mymarketresearchmethods.com/types-of-charts-choose/
# * Seaborn box plot https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# **Try plotly!** More interactive than *Seaborn* https://plotly.com/python/box-plots/
#
# * https://matplotlib.org/stable/gallery/lines_bars_and_markers/horizontal_barchart_distribution.html
#
# ### Notwendige Änderungen?
# * ABSOLUTE oder RELATIVE Häufigkeit?
# * Kategorie 7, 8, 9 ausblenden?

# %%
#TRY scatterplots

# %%
# TRY bubble plot
#try this plot: https://seaborn.pydata.org/examples/scatter_bubbles.html
# https://www.python-graph-gallery.com/bubble-plot-with-seaborn


#sns.boxplot(x=df_round9['cntry'], y=df_round9['imprich'], data=df_round9)

#sns.scatterplot(data=df_round9, x=df_round9['imprich'], y=df_round9['cntry'], alpha=0.9, size=(10,100))
#plt.show()


sns.scatterplot(
    data=tips, x=df_round9['imprich'], y=df_round9['cntry'], hue='size', size="size",
    sizes=(20, 200), legend="full")

plt.show()

# %%
# TRY plotly

# %%
# choose one example to visualize 
data['imprich'].value_counts()
# Out:
# 5    8567
# 4    4244
# 3    3184
# 6    2982
# 2    1466
# 1     532
# 9     337
# 8     247
# 7     147
# Name: imprich, dtype: int64

# %%
# create dictionary

dict_imprich = data['imprich'].value_counts().to_dict()
dict_imprich
# Out:
# {5: 8567, 4: 4244, 3: 3184, 6: 2982, 2: 1466, 1: 532, 9: 337, 8: 247, 7: 147}

# %%
# change keys! --> ADD full answers

dict_imprich2 = data['imprich'].value_counts().to_dict()
dict_imprich2['1'] = dict_imprich2.pop(h')#CHANGE
dict_imprich2
# Out:
#   Input In [39]
#     dict_imprich2['1'] = dict_imprich2.pop(h')#CHANGE
#                                                      ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# https://www.geeksforgeeks.org/python-ways-to-change-keys-in-dictionary/
#
# use pop-method to rename key in dictionary : ini_dict['akash'] = ini_dict.pop('akshat')

# %%
df_imprich = pd.DataFrame.from_dict(dict_imprich, orient='index', columns=['count'])
df_imprich.index.name = 'imprich - Value Category'
df_imprich = df_imprich.sort_index()
df_imprich
# Out:
#                           count
# imprich - Value Category
# 1                           532
# 2                          1466
# 3                          3184
# 4                          4244
# 5                          8567
# 6                          2982
# 7                           147
# 8                           247
# 9                           337

# %% [markdown]
# seaborn, grouped boxplot: https://seaborn.pydata.org/examples/grouped_boxplot.html
